# %% [markdown]
# # Topological Lie Detector - Colab Demo\nRun the standalone pipeline in all three modes.

# %%
# !git clone <YOUR_REPO_URL>\n%cd topological-lie-detector\n!pip install -r requirements.txt

# %% [markdown]
# Place ACL2017 in `./data/acl2017` before running experiments.

# %%
# !python run.py --mode tda_only --data_path ./data/acl2017 --max_events 200 --epochs 5

# %%
# !python run.py --mode text_only --data_path ./data/acl2017 --max_events 200 --epochs 5

# %%
# !python run.py --mode hybrid --data_path ./data/acl2017 --max_events 200 --epochs 5

# %%
import json\nfrom pathlib import Path\nresult_file = Path('results/results.json')\nif result_file.exists():\n    print(result_file.read_text())\nelse:\n    print('results/results.json not found. Check run logs.')
